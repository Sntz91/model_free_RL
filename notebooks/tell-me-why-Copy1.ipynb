# %%
import numpy as np
import os
os.environ.setdefault('PATH', '')
from collections import deque
import gym
from gym import spaces


USE_PIL = True
if USE_PIL:
    # you should use pillow-simd, as it is faster than stardand Pillow
    from PIL import Image
else:
    import cv2
    cv2.ocl.setUseOpenCL(False)


class TimeLimit(gym.Wrapper):
    def __init__(self, env, max_episode_steps=None):
        super(TimeLimit, self).__init__(env)
        self._max_episode_steps = max_episode_steps
        self._elapsed_steps = 0

    def step(self, ac):
        observation, reward, done, info = self.env.step(ac)
        self._elapsed_steps += 1
        if self._elapsed_steps >= self._max_episode_steps:
            done = True
            info['TimeLimit.truncated'] = True
        return observation, reward, done, info

    def reset(self, **kwargs):
        self._elapsed_steps = 0
        return self.env.reset(**kwargs)

class ClipActionsWrapper(gym.Wrapper):
    def step(self, action):
        import numpy as np
        action = np.nan_to_num(action)
        action = np.clip(action, self.action_space.low, self.action_space.high)
        return self.env.step(action)

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)


class NoopResetEnv(gym.Wrapper):
    def __init__(self, env, noop_max=30):
        """Sample initial states by taking random number of no-ops on reset.
        No-op is assumed to be action 0.
        """
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def reset(self, **kwargs):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1) #pylint: disable=E1101
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
        """Take action on reset for environments that are fixed until firing."""
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs

    def step(self, ac):
        return self.env.step(ac)

class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done  = True

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert sometimes we stay in lives == 0 condition for a few frames
            # so it's important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self, **kwargs):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs

class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,)+env.observation_space.shape, dtype=np.uint8)
        self._skip       = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2: self._obs_buffer[0] = obs
            if i == self._skip - 1: self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)


class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84, grayscale=True, dict_space_key=None):
        """
        Warp frames to 84x84 as done in the Nature paper and later work.
        If the environment uses dictionary observations, `dict_space_key` can be specified which indicates which
        observation should be warped.
        """
        super().__init__(env)
        self._width = width
        self._height = height
        self._grayscale = grayscale
        self._key = dict_space_key
        if self._grayscale:
            num_colors = 1
        else:
            num_colors = 3

        new_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(self._height, self._width, num_colors),
            dtype=np.uint8,
        )
        if self._key is None:
            original_space = self.observation_space
            self.observation_space = new_space
        else:
            original_space = self.observation_space.spaces[self._key]
            self.observation_space.spaces[self._key] = new_space
        assert original_space.dtype == np.uint8 and len(original_space.shape) == 3

    def observation(self, obs):
        if self._key is None:
            frame = obs
        else:
            frame = obs[self._key]
        if USE_PIL:
            frame = Image.fromarray(frame)
            if self._grayscale:
                frame = frame.convert("L")
            frame = frame.resize((self._width, self._height))
            frame = np.array(frame)
        else:
            if self._grayscale:
                frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
            frame = cv2.resize(
                frame, (self._width, self._height),
                interpolation=cv2.INTER_AREA
            )
        if self._grayscale:
            frame = np.expand_dims(frame, -1)

        if self._key is None:
            obs = frame
        else:
            obs = obs.copy()
            obs[self._key] = frame
        return obs

class LazyFrames(object):
    def __init__(self, frames):
        """This object ensures that common frames between the observations are only stored once.
        It exists purely to optimize memory usage which can be huge for DQN's 1M frames replay
        buffers.
        This object should only be converted to numpy array before being passed to the model.
        You'd not believe how complex the previous solution was."""
        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=0)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]

    def count(self):
        frames = self._force()
        return frames.shape[1:frames.ndim]

    def frame(self, i):
        return self._force()[i, ...]


class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.
        Returns lazy array, which is much more memory efficient.
        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = spaces.Box(low=0, high=255, shape=(shp[0]*k, shp[1], shp[2]), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))

class ScaledFloatFrame(gym.ObservationWrapper):
    def __init__(self, env):
        gym.ObservationWrapper.__init__(self, env)
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=env.observation_space.shape, dtype=np.float32)

    def observation(self, observation):
        # careful! This undoes the memory optimization, use
        # with smaller replay buffers only.
        return np.array(observation).astype(np.float32) / 255.0

class SkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        gym.Wrapper.__init__(self, env)
        self._skip       = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)


def make_atari(env_id, max_episode_steps=None,
               skip_noop=False, skip_maxskip=False):
    env = gym.make(env_id)
    assert 'NoFrameskip' in env.spec.id
    if not skip_noop:
        env = NoopResetEnv(env, noop_max=30) #no
    if not skip_maxskip:
        env = MaxAndSkipEnv(env, skip=4) #yes
    else:
        env = SkipEnv(env, skip=4)
    if max_episode_steps is not None:
        env = TimeLimit(env, max_episode_steps=max_episode_steps)
    return env


class ImageToPyTorch(gym.ObservationWrapper):
    """
    Change image shape to CWH
    """
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        new_shape = (old_shape[-1], old_shape[0], old_shape[1])
        self.observation_space = gym.spaces.Box(
            low=0.0, high=1.0, shape=new_shape, dtype=np.uint8)

    def observation(self, observation):
        return np.swapaxes(observation, 2, 0)


def wrap_deepmind(env, episode_life=True, clip_rewards=True,
                  frame_stack=False, scale=False, pytorch_img=False,
                  frame_stack_count=4, skip_firereset=False):
    """Configure environment for DeepMind-style Atari.
    """
    if episode_life:
        env = EpisodicLifeEnv(env)
    if 'FIRE' in env.unwrapped.get_action_meanings():
        if not skip_firereset:
            env = FireResetEnv(env) #yes
    env = WarpFrame(env)
    if pytorch_img:
        env = ImageToPyTorch(env) #yes
    if scale:
        env = ScaledFloatFrame(env)
    if clip_rewards:
        env = ClipRewardEnv(env)
    if frame_stack:
        env = FrameStack(env, frame_stack_count)
    return env

# %%
from typing import Tuple, List, Union
from collections import namedtuple, deque


Experience = namedtuple("Experience", 
                            field_names = ["state", "action", "reward", "done", "next_state"])



class ReplayMemory:
    """
    Original Replay Memory by Lin. Used for vanilla DQN, no prioritized Replay or bootstrapping with n>1.
    Used to store and sample experiences
    """
    def __init__(self, capacity: int) -> None:
        """
        Args: 
            capacity: size of buffer
        """
        self.buffer = deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, sample: Experience) -> None:
        """
        Append sample
        Args:
            sample: A sample of an experience to store. Experience is a tuple(state, action, reward, done, next_state)
        """
        self.buffer.append(sample)

    def sample(self, batch_size: int = 1) -> Tuple:
        """
        Return batch of buffer, randomly (uniformely).
        Args: 
            batch_size: size of batch
        """
        idxs = np.random.choice(len(self), batch_size, replace=False)

        states, actions, rewards, dones, next_states = \
            zip(*[self.buffer[idx] for idx in idxs])

        return np.array(states), np.array(actions), \
            np.array(rewards, dtype=np.float32), np.array(dones, dtype=bool), \
            np.array(next_states)

    

    

   


import torch
import torch.nn as nn
    
class DQN(nn.Module):
    """
    Neural Network, choosing actions
    """
    def __init__(self, n_in, n_out):
        super(DQN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(n_in[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(n_in)

        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_out)
        )

        self.dtype = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor #here

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        x = x.type(self.dtype) #!!! not sure. I need this, because the images are now stored as uint8 and not float32 anymore
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

# %%
import torch.optim as optim
import torch.nn.functional as F
import time

RM_CAPACITY = 100000
GAMMA = 0.99
N_EPISODES = 1000
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_DECAY_LAST_FRAME = 100000
LEARNING_RATE = 0.00001
MEMORY_START_SIZE = 10000
BATCH_SIZE = 32
TARGET_UPDATE_AFTER = 10000

frame_idx = 0
ts_frame = 0 
obtained_returns = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
replay_memory = ReplayMemory(RM_CAPACITY)
env_name = 'PongNoFrameskip-v4'
env = make_atari(env_name, skip_noop=False, skip_maxskip=True)
env = wrap_deepmind(env, pytorch_img=True, frame_stack=False)

target_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
policy_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)


def calc_loss_old(batch, policy_net, target_net, device=device):
    states, actions, rewards, dones, next_states = batch
    
    states_v = torch.from_numpy(states).to(device)
    next_states_v = torch.from_numpy(next_states).to(device)
    actions_v = torch.from_numpy(actions).to(device)
    rewards_v = torch.from_numpy(rewards).to(device)
    done_mask = torch.BoolTensor(dones).to(device)
    
    state_action_values = policy_net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    
    with torch.no_grad():
        next_state_values = target_net(next_states_v).max(1)[0]
        next_state_values[done_mask] = 0.0
    next_state_values = next_state_values.detach()
    expected_state_action_values = (next_state_values * GAMMA) + rewards_v
    
    return F.smooth_l1_loss(state_action_values, expected_state_action_values)

def calc_loss(batch, policy_net, target_net, device=device):
    """
        Calculate L1-Loss for given batch.
    """
    states, actions, rewards, dones, next_states = batch

    states_v = torch.from_numpy(states).to(device)
    next_states_v = torch.from_numpy(next_states).to(device)
    actions_v = torch.from_numpy(actions).to(device)
    rewards_v = torch.from_numpy(rewards).to(device)
    done_mask = torch.BoolTensor(dones).to(device)

    state_action_values = policy_net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)

    with torch.no_grad():
        next_state_values = target_net(next_states_v).max(1)[0]
        next_state_values[done_mask] = 0.0
    next_state_values = next_state_values.detach()
    expected_state_action_values = (next_state_values * GAMMA) + rewards_v

    return F.smooth_l1_loss(state_action_values, expected_state_action_values)


#EPSILON

#don't need two loops...

for episode in range(N_EPISODES):
    print("Start episode %d" % episode)
    state = env.reset()
    return_val = 0
    done=False
    ts = time.time()
    
    while(not done):
        frame_idx += 1
        epsilon = max(EPSILON_END, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)
        
        #Play Step
        if(np.random.random() < epsilon):
            action = env.action_space.sample()
        else:
            q_vals = policy_net(torch.tensor(np.array([state], copy=False)).to(device))
            _, action = torch.max(q_vals, dim=1)
            action = int(action.item())
        
        next_state, reward, done, _ = env.step(action)
        
        return_val += reward
    
        
        
        #save experience
        exp = Experience(state, action, reward, done, next_state)
        replay_memory.append(exp)
        
        state = next_state

        if(len(replay_memory) > MEMORY_START_SIZE):
            #learning (outsourcen spaeter!)
            optimizer.zero_grad()
       
            batch = replay_memory.sample(BATCH_SIZE)
            loss_t = calc_loss(batch, policy_net, target_net, device=device)
            loss_t.backward()
            optimizer.step()
            
          
        
        if frame_idx % TARGET_UPDATE_AFTER == 0:
            target_net.load_state_dict(policy_net.state_dict())
            
    
    
    print("frame_idx = %2f, ts = %2f, tsframe = %2f, time = %2f" % (frame_idx, ts, ts_frame, time.time()))
    speed = (frame_idx - ts_frame) / (time.time() - ts)
    ts_frame = frame_idx
    ts = time.time()
    
    
    print("Episode %d completed, timesteps played: %d, return: %d, speed: %f, epsilon: %f" 
                            % (episode, frame_idx, return_val, speed, epsilon))
    obtained_returns.append(return_val)
    m_reward = np.mean(obtained_returns[-100:])
    print("Mean return of last 100 games: %f" % m_reward)
# Out:
# Start episode 0
# frame_idx = 849.000000, ts = 1621348988.177198, tsframe = 0.000000, time = 1621348988.842739
# Episode 0 completed, timesteps played: 849, return: -21, speed: 1275.522015, epsilon: 0.991510
# Mean return of last 100 games: -21.000000
# Start episode 1
# frame_idx = 1697.000000, ts = 1621348988.851435, tsframe = 849.000000, time = 1621348989.519976
# Episode 1 completed, timesteps played: 1697, return: -21, speed: 1268.319449, epsilon: 0.983030
# Mean return of last 100 games: -21.000000
# Start episode 2
# frame_idx = 2512.000000, ts = 1621348989.529930, tsframe = 1697.000000, time = 1621348990.176505
# Episode 2 completed, timesteps played: 2512, return: -21, speed: 1260.369030, epsilon: 0.974880
# Mean return of last 100 games: -21.000000
# Start episode 3
# frame_idx = 3573.000000, ts = 1621348990.187931, tsframe = 2512.000000, time = 1621348991.023861
# Episode 3 completed, timesteps played: 3573, return: -19, speed: 1269.146771, epsilon: 0.964270
# Mean return of last 100 games: -20.500000
# Start episode 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-aa52308b3ca2> in <module>
#      96             action = int(action.item())
#      97
# ---> 98         next_state, reward, done, _ = env.step(action)
#      99
#     100         return_val += reward
#
# ~/.local/lib/python3.8/site-packages/gym/core.py in step(self, action)
#     278
#     279     def step(self, action):
# --> 280         observation, reward, done, info = self.env.step(action)
#     281         return observation, self.reward(reward), done, info
#     282
#
# ~/.local/lib/python3.8/site-packages/gym/core.py in step(self, action)
#     266
#     267     def step(self, action):
# --> 268         observation, reward, done, info = self.env.step(action)
#     269         return self.observation(observation), reward, done, info
#     270
#
# ~/.local/lib/python3.8/site-packages/gym/core.py in step(self, action)
#     267     def step(self, action):
#     268         observation, reward, done, info = self.env.step(action)
# --> 269         return self.observation(observation), reward, done, info
#     270
#     271     def observation(self, observation):
#
# <ipython-input-1-8ef2b456ee15> in observation(self, obs)
#     207             if self._grayscale:
#     208                 frame = frame.convert("L")
# --> 209             frame = frame.resize((self._width, self._height))
#     210             frame = np.array(frame)
#     211         else:
#
# /usr/lib/python3/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1871                 )
#    1872
# -> 1873         return self._new(self.im.resize(size, resample, box))
#    1874
#    1875     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:

# %%
batch = replay_memory.sample(2)
states, actions, rewards, dones, next_states = batch

states_v = torch.from_numpy(states).to(device)
next_states_v = torch.from_numpy(next_states).to(device)
actions_v = torch.from_numpy(actions).to(device)
rewards_v = torch.from_numpy(rewards).to(device)
done_mask = torch.BoolTensor(dones).to(device)
    
next_state_values = target_net(next_states_v).max(1)[1] #passt vom shape
next_state_values
#target_net(next_states_v).gather(1, [1,2])
# Out:
# tensor([0, 0], device='cuda:0')

# %%
class DQN(nn.Module):
    def __init__(self, n_in, n_out):
        super(DQN, self).__init__()

        self.fc = nn.Sequential(
            nn.Linear(n_in[0], 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, n_out)
        )


    def forward(self, x):
        return self.fc(x)

# %%
import torch.optim as optim
import torch.nn.functional as F
import time

RM_CAPACITY = 100000
GAMMA = 0.99
N_EPISODES = 1000
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_DECAY_LAST_FRAME = 100000
LEARNING_RATE = 0.00001
MEMORY_START_SIZE = 10000
BATCH_SIZE = 32
TARGET_UPDATE_AFTER = 10000

frame_idx = 0
ts_frame = 0 
obtained_returns = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
replay_memory = ReplayMemory(RM_CAPACITY)
ENV_NAME = "CartPole-v0"
env = gym.make(ENV_NAME)
target_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
policy_net = DQN(env.observation_space.shape, env.action_space.n).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)


def calc_loss(batch, net, tgt_net, device=device):
    states, actions, rewards, dones, next_states = batch
    
    states_v = torch.from_numpy(states).to(device)
    next_states_v = torch.from_numpy(next_states).to(device)
    actions_v = torch.from_numpy(actions).to(device)
    rewards_v = torch.from_numpy(rewards).to(device)
    done_mask = torch.BoolTensor(dones).to(device)
    
    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    
    with torch.no_grad():
        next_state_values = target_net(next_states_v).max(1)[0]
        next_state_values[done_mask] = 0.0
    next_state_values = next_state_values.detach()
    expected_state_action_values = (next_state_values * GAMMA) + rewards_v
    
    return F.smooth_l1_loss(state_action_values, expected_state_action_values)



#EPSILON

#don't need two loops...

for episode in range(N_EPISODES):
    print("Start episode %d" % episode)
    state = env.reset().astype('float32')
    print(state.dtype)
    return_val = 0
    done=False
    ts = time.time()
    
    while(not done):
        frame_idx += 1
        epsilon = max(EPSILON_END, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)
        
        #Play Step
        if(np.random.random() < epsilon):
            action = env.action_space.sample()
        else:
            q_vals = policy_net(torch.tensor(np.array([state], copy=False)).to(device))
            _, action = torch.max(q_vals, dim=1)
            action = int(action.item())
        
        next_state, reward, done, _ = env.step(action)
        next_state = next_state.astype('float32')
        
        return_val += reward
    
        
        
        #save experience
        exp = Experience(state, action, reward, done, next_state)
        replay_memory.add(exp)
        
        state = next_state

        if(len(replay_memory) > MEMORY_START_SIZE):
            #learning (outsourcen spaeter!)
            optimizer.zero_grad()
       
            batch = replay_memory.sample(BATCH_SIZE)
            loss_t = calc_loss(batch, policy_net, target_net, device=device)
            loss_t.backward()
            optimizer.step()
            
          
        
        if frame_idx % TARGET_UPDATE_AFTER == 0:
            target_net.load_state_dict(policy_net.state_dict())
            
    
    
    print("frame_idx = %2f, ts = %2f, tsframe = %2f, time = %2f" % (frame_idx, ts, ts_frame, time.time()))
    speed = (frame_idx - ts_frame) / (time.time() - ts)
    ts_frame = frame_idx
    ts = time.time()
    
    
    print("Episode %d completed, timesteps played: %d, return: %d, speed: %f, epsilon: %f" 
                            % (episode, frame_idx, return_val, speed, epsilon))
    obtained_returns.append(return_val)
    m_reward = np.mean(obtained_returns[-100:])
    print("Mean return of last 100 games: %f" % m_reward)
# Out:
# Start episode 0
# float32
# Mean return of last 100 games: 27.538462
# Start episode 13
# float32
# frame_idx = 370.000000, ts = 1619447718.817535, tsframe = 358.000000, time = 1619447718.817698
# Episode 13 completed, timesteps played: 370, return: 12, speed: 68200.065041, epsilon: 0.996300
# Mean return of last 100 games: 26.428571
# Start episode 14
# float32
# frame_idx = 390.000000, ts = 1619447718.818246, tsframe = 370.000000, time = 1619447718.818692
# Episode 14 completed, timesteps played: 390, return: 20, speed: 35787.576792, epsilon: 0.996100
# Mean return of last 100 games: 26.000000
# Start episode 15
# float32
# frame_idx = 400.000000, ts = 1619447718.818914, tsframe = 390.000000, time = 1619447718.819152
# Episode 15 completed, timesteps played: 400, return: 10, speed: 38621.583794, epsilon: 0.996000
# Mean return of last 100 games: 25.000000
# Start episode 16
# float32
# frame_idx = 456.000000, ts = 1619447718.819278, tsframe = 400.000000, time = 1619447718.821670
# Episode 16 completed, timesteps played: 456, return: 56, speed: 23054.674519, epsilon: 0.995440
# Mean return of last 100 games: 26.823529
# Start episode 17
# float32
# frame_idx = 466.000000, ts = 1619447718.821841, tsframe = 456.000000, time = 1619447718.822088
# Episode 17 completed, timesteps played: 466, return: 10, speed: 37084.916004, epsilon: 0.995340
# Mean return of last 100 games: 25.888889
# Start episode 18
# float32
# frame_idx = 478.000000, ts = 1619447718.822237, tsframe = 466.000000, time = 1619447718.822524
# Episode 18 completed, timesteps played: 478, return: 12, speed: 12693.984363, epsilon: 0.995220
# Mean return of last 100 games: 25.157895
# Start episode 19
# float32
# frame_idx = 494.000000, ts = 1619447718.823321, tsframe = 478.000000, time = 1619447718.823703
# Episode 19 completed, timesteps played: 494, return: 16, speed: 21795.668724, epsilon: 0.995060
# Mean return of last 100 games: 24.700000
# Start episode 20
# float32
# frame_idx = 531.000000, ts = 1619447718.824194, tsframe = 494.000000, time = 1619447718.825638
# Episode 20 completed, timesteps played: 531, return: 37, speed: 24994.241907, epsilon: 0.994690
# Mean return of last 100 games: 25.285714
# Start episode 21
# float32
# frame_idx = 543.000000, ts = 1619447718.825810, tsframe = 531.000000, time = 1619447718.826106
# Episode 21 completed, timesteps played: 543, return: 12, speed: 37421.299628, epsilon: 0.994570
# Mean return of last 100 games: 24.681818
# Start episode 22
# float32
# frame_idx = 561.000000, ts = 1619447718.826253, tsframe = 543.000000, time = 1619447718.826671
# Episode 22 completed, timesteps played: 561, return: 18, speed: 17311.963311, epsilon: 0.994390
# Mean return of last 100 games: 24.391304
# Start episode 23
# float32
# frame_idx = 590.000000, ts = 1619447718.827384, tsframe = 561.000000, time = 1619447718.827824
# Episode 23 completed, timesteps played: 590, return: 29, speed: 42995.693178, epsilon: 0.994100
# Mean return of last 100 games: 24.583333
# Start episode 24
# float32
# frame_idx = 632.000000, ts = 1619447718.828150, tsframe = 590.000000, time = 1619447718.828784
# Episode 24 completed, timesteps played: 632, return: 42, speed: 48289.684211, epsilon: 0.993680
# Mean return of last 100 games: 25.280000
# Start episode 25
# float32
# frame_idx = 647.000000, ts = 1619447718.829111, tsframe = 632.000000, time = 1619447718.829346
# Episode 25 completed, timesteps played: 647, return: 15, speed: 59634.654028, epsilon: 0.993530
# Episode 38 completed, timesteps played: 910, return: 11, speed: 56265.053659, epsilon: 0.990900
# Mean return of last 100 games: 23.333333
# Start episode 39
# float32
# frame_idx = 929.000000, ts = 1619447718.837576, tsframe = 910.000000, time = 1619447718.837866
# Episode 39 completed, timesteps played: 929, return: 19, speed: 27254.369357, epsilon: 0.990710
# Mean return of last 100 games: 23.225000
# Start episode 40
# float32
# frame_idx = 941.000000, ts = 1619447718.838366, tsframe = 929.000000, time = 1619447718.838558
# Episode 40 completed, timesteps played: 941, return: 12, speed: 57653.663230, epsilon: 0.990590
# Mean return of last 100 games: 22.951220
# Start episode 41
# float32
# frame_idx = 960.000000, ts = 1619447718.838657, tsframe = 941.000000, time = 1619447718.838950
# Episode 41 completed, timesteps played: 960, return: 19, speed: 26959.328823, epsilon: 0.990400
# Mean return of last 100 games: 22.857143
# Start episode 42
# float32
# frame_idx = 995.000000, ts = 1619447718.839454, tsframe = 960.000000, time = 1619447718.840533
# Episode 42 completed, timesteps played: 995, return: 35, speed: 31720.103717, epsilon: 0.990050
# Mean return of last 100 games: 23.139535
# Start episode 43
# float32
# frame_idx = 1035.000000, ts = 1619447718.840645, tsframe = 995.000000, time = 1619447718.841796
# Episode 43 completed, timesteps played: 1035, return: 40, speed: 34037.768310, epsilon: 0.989650
# Mean return of last 100 games: 23.522727
# Start episode 44
# float32
# frame_idx = 1050.000000, ts = 1619447718.841910, tsframe = 1035.000000, time = 1619447718.842146
# Episode 44 completed, timesteps played: 1050, return: 15, speed: 59578.181818, epsilon: 0.989500
# Mean return of last 100 games: 23.333333
# Start episode 45
# float32
# frame_idx = 1090.000000, ts = 1619447718.842246, tsframe = 1050.000000, time = 1619447718.842845
# Episode 45 completed, timesteps played: 1090, return: 40, speed: 38971.465738, epsilon: 0.989100
# Mean return of last 100 games: 23.695652
# Start episode 46
# float32
# frame_idx = 1105.000000, ts = 1619447718.843367, tsframe = 1090.000000, time = 1619447718.843606
# Episode 46 completed, timesteps played: 1105, return: 15, speed: 58634.259087, epsilon: 0.988950
# Mean return of last 100 games: 23.510638
# Start episode 47
# float32
# frame_idx = 1122.000000, ts = 1619447718.844004, tsframe = 1105.000000, time = 1619447718.844664
# Episode 47 completed, timesteps played: 1122, return: 17, speed: 24827.008357, epsilon: 0.988780
# Mean return of last 100 games: 23.375000
# Start episode 48
# float32
# frame_idx = 1157.000000, ts = 1619447718.844782, tsframe = 1122.000000, time = 1619447718.845309
# Episode 48 completed, timesteps played: 1157, return: 35, speed: 64442.774363, epsilon: 0.988430
# Mean return of last 100 games: 23.612245
# Start episode 49
# float32
# frame_idx = 1184.000000, ts = 1619447718.845408, tsframe = 1157.000000, time = 1619447718.845818
# Episode 49 completed, timesteps played: 1184, return: 27, speed: 31999.493642, epsilon: 0.988160
# Mean return of last 100 games: 23.680000
# Start episode 50
# float32
# frame_idx = 1199.000000, ts = 1619447718.846346, tsframe = 1184.000000, time = 1619447718.846587
# Episode 50 completed, timesteps played: 1199, return: 15, speed: 58308.211307, epsilon: 0.988010
# Mean return of last 100 games: 23.509804
# Start episode 51
# float32
# frame_idx = 1218.000000, ts = 1619447718.846982, tsframe = 1199.000000, time = 1619447718.847279
# Episode 51 completed, timesteps played: 1218, return: 19, speed: 60694.421935, epsilon: 0.987820
# Mean return of last 100 games: 23.423077
# Start episode 52
# float32
# frame_idx = 1230.000000, ts = 1619447718.847383, tsframe = 1218.000000, time = 1619447718.847574
# Episode 52 completed, timesteps played: 1230, return: 12, speed: 22712.837545, epsilon: 0.987700
# Mean return of last 100 games: 23.207547
# Start episode 53
# float32
# frame_idx = 1240.000000, ts = 1619447718.848003, tsframe = 1230.000000, time = 1619447718.848174
# Episode 53 completed, timesteps played: 1240, return: 10, speed: 53498.775510, epsilon: 0.987600
# Mean return of last 100 games: 22.962963
# Start episode 54
# float32
# frame_idx = 1252.000000, ts = 1619447718.848272, tsframe = 1240.000000, time = 1619447718.848464
# Episode 54 completed, timesteps played: 1252, return: 12, speed: 19706.988254, epsilon: 0.987480
# Mean return of last 100 games: 22.763636
# Start episode 55
# float32
# frame_idx = 1280.000000, ts = 1619447718.848975, tsframe = 1252.000000, time = 1619447718.849404
# Episode 55 completed, timesteps played: 1280, return: 28, speed: 42458.608821, epsilon: 0.987200
# Mean return of last 100 games: 22.857143
# Start episode 56
# float32
# frame_idx = 1299.000000, ts = 1619447718.849727, tsframe = 1280.000000, time = 1619447718.850026
# Episode 56 completed, timesteps played: 1299, return: 19, speed: 60372.557576, epsilon: 0.987010
# Mean return of last 100 games: 22.789474
# Start episode 57
# float32
# frame_idx = 1336.000000, ts = 1619447718.850126, tsframe = 1299.000000, time = 1619447718.850708
# Episode 57 completed, timesteps played: 1336, return: 37, speed: 37117.734513, epsilon: 0.986640
# Mean return of last 100 games: 23.034483
# Start episode 58
# float32
# frame_idx = 1345.000000, ts = 1619447718.851217, tsframe = 1336.000000, time = 1619447718.851369
# Episode 58 completed, timesteps played: 1345, return: 9, speed: 53696.637269, epsilon: 0.986550
# Mean return of last 100 games: 22.796610
# Start episode 59
# float32
# frame_idx = 1356.000000, ts = 1619447718.851468, tsframe = 1345.000000, time = 1619447718.851645
# Episode 59 completed, timesteps played: 1356, return: 11, speed: 18793.215479, epsilon: 0.986440
# Mean return of last 100 games: 22.600000
# Start episode 60
# float32
# frame_idx = 1367.000000, ts = 1619447718.852146, tsframe = 1356.000000, time = 1619447718.852326
# Episode 60 completed, timesteps played: 1367, return: 11, speed: 55991.922330, epsilon: 0.986330
# Mean return of last 100 games: 22.409836
# Start episode 61
# float32
# frame_idx = 1376.000000, ts = 1619447718.852425, tsframe = 1367.000000, time = 1619447718.852581
# Episode 61 completed, timesteps played: 1376, return: 9, speed: 21682.214819, epsilon: 0.986240
# Mean return of last 100 games: 22.193548
# Start episode 62
# float32
# frame_idx = 1391.000000, ts = 1619447718.852932, tsframe = 1376.000000, time = 1619447718.853173
# Episode 62 completed, timesteps played: 1391, return: 15, speed: 58416.490251, epsilon: 0.986090
# Mean return of last 100 games: 22.079365
# Start episode 63
# float32
# frame_idx = 1406.000000, ts = 1619447718.853273, tsframe = 1391.000000, time = 1619447718.854284
# Episode 63 completed, timesteps played: 1406, return: 15, speed: 14459.793151, epsilon: 0.985940
# Mean return of last 100 games: 21.968750
# Start episode 64
# float32
# frame_idx = 1440.000000, ts = 1619447718.854402, tsframe = 1406.000000, time = 1619447718.855304
# Episode 64 completed, timesteps played: 1440, return: 34, speed: 36697.461657, epsilon: 0.985600
# Mean return of last 100 games: 22.153846
# Start episode 65
# float32
# frame_idx = 1479.000000, ts = 1619447718.855419, tsframe = 1440.000000, time = 1619447718.856004
# Episode 65 completed, timesteps played: 1479, return: 39, speed: 64834.663496, epsilon: 0.985210
# Mean return of last 100 games: 22.409091
# Start episode 66
# float32
# frame_idx = 1508.000000, ts = 1619447718.856501, tsframe = 1479.000000, time = 1619447718.857119
# Episode 66 completed, timesteps played: 1508, return: 29, speed: 44966.660259, epsilon: 0.984920
# Mean return of last 100 games: 22.507463
# Start episode 67
# float32
# frame_idx = 1529.000000, ts = 1619447718.857239, tsframe = 1508.000000, time = 1619447718.857562
# Episode 67 completed, timesteps played: 1529, return: 21, speed: 61680.941176, epsilon: 0.984710
# Mean return of last 100 games: 22.485294
# Start episode 68
# float32
# frame_idx = 1543.000000, ts = 1619447718.857665, tsframe = 1529.000000, time = 1619447718.858527
# Episode 68 completed, timesteps played: 1543, return: 14, speed: 15806.260027, epsilon: 0.984570
# Mean return of last 100 games: 22.362319
# Start episode 69
# float32
# frame_idx = 1580.000000, ts = 1619447718.858641, tsframe = 1543.000000, time = 1619447718.859197
# Episode 69 completed, timesteps played: 1580, return: 37, speed: 64743.115561, epsilon: 0.984200
# Mean return of last 100 games: 22.571429
# Start episode 70
# float32
# frame_idx = 1602.000000, ts = 1619447718.859298, tsframe = 1580.000000, time = 1619447718.859637
# Episode 70 completed, timesteps played: 1602, return: 22, speed: 28790.854290, epsilon: 0.983980
# Mean return of last 100 games: 22.563380
# Start episode 71
# float32
# frame_idx = 1616.000000, ts = 1619447718.860155, tsframe = 1602.000000, time = 1619447718.860378
# Episode 71 completed, timesteps played: 1616, return: 14, speed: 58603.049900, epsilon: 0.983840
# Mean return of last 100 games: 22.444444
# Start episode 72
# float32
# frame_idx = 1647.000000, ts = 1619447718.860818, tsframe = 1616.000000, time = 1619447718.861290
# Episode 72 completed, timesteps played: 1647, return: 31, speed: 51947.033160, epsilon: 0.983530
# Mean return of last 100 games: 22.561644
# Start episode 73
# float32
# frame_idx = 1672.000000, ts = 1619447718.861509, tsframe = 1647.000000, time = 1619447718.861890
# Episode 73 completed, timesteps played: 1672, return: 25, speed: 62788.982036, epsilon: 0.983280
# Mean return of last 100 games: 22.594595
# Start episode 74
# float32
# frame_idx = 1684.000000, ts = 1619447718.861990, tsframe = 1672.000000, time = 1619447718.862182
# Episode 74 completed, timesteps played: 1684, return: 12, speed: 19972.876190, epsilon: 0.983160
# Mean return of last 100 games: 22.453333
# Start episode 75
# float32
# frame_idx = 1712.000000, ts = 1619447718.862685, tsframe = 1684.000000, time = 1619447718.863724
# Episode 75 completed, timesteps played: 1712, return: 28, speed: 26343.766712, epsilon: 0.982880
# Mean return of last 100 games: 22.526316
# Start episode 76
# float32
# Episode 163 completed, timesteps played: 3585, return: 13, speed: 23665.777778, epsilon: 0.964150
# Mean return of last 100 games: 21.790000
# Start episode 164
# float32
# frame_idx = 3648.000000, ts = 1619447718.931110, tsframe = 3585.000000, time = 1619447718.932586
# Episode 164 completed, timesteps played: 3648, return: 63, speed: 42036.454343, epsilon: 0.963520
# Mean return of last 100 games: 22.080000
# Start episode 165
# float32
# frame_idx = 3658.000000, ts = 1619447718.932701, tsframe = 3648.000000, time = 1619447718.932866
# Episode 165 completed, timesteps played: 3658, return: 10, speed: 55260.922266, epsilon: 0.963420
# Mean return of last 100 games: 21.790000
# Start episode 166
# float32
# frame_idx = 3672.000000, ts = 1619447718.932966, tsframe = 3658.000000, time = 1619447718.933187
# Episode 166 completed, timesteps played: 3672, return: 14, speed: 58896.946841, epsilon: 0.963280
# Mean return of last 100 games: 21.640000
# Start episode 167
# float32
# frame_idx = 3692.000000, ts = 1619447718.933287, tsframe = 3672.000000, time = 1619447718.934405
# Episode 167 completed, timesteps played: 3692, return: 20, speed: 17494.490094, epsilon: 0.963080
# Mean return of last 100 games: 21.630000
# Start episode 168
# float32
# frame_idx = 3706.000000, ts = 1619447718.934521, tsframe = 3692.000000, time = 1619447718.935182
# Episode 168 completed, timesteps played: 3706, return: 14, speed: 20474.287308, epsilon: 0.962940
# Mean return of last 100 games: 21.630000
# Start episode 169
# float32
# frame_idx = 3717.000000, ts = 1619447718.935393, tsframe = 3706.000000, time = 1619447718.935939
# Episode 169 completed, timesteps played: 3717, return: 11, speed: 19344.798323, epsilon: 0.962830
# Mean return of last 100 games: 21.370000
# Start episode 170
# float32
# frame_idx = 3733.000000, ts = 1619447718.936206, tsframe = 3717.000000, time = 1619447718.936765
# Episode 170 completed, timesteps played: 3733, return: 16, speed: 27514.909389, epsilon: 0.962670
# Mean return of last 100 games: 21.310000
# Start episode 171
# float32
# frame_idx = 3756.000000, ts = 1619447718.936993, tsframe = 3733.000000, time = 1619447718.937699
# Episode 171 completed, timesteps played: 3756, return: 23, speed: 31536.120301, epsilon: 0.962440
# Mean return of last 100 games: 21.400000
# Start episode 172
# float32
# frame_idx = 3767.000000, ts = 1619447718.937814, tsframe = 3756.000000, time = 1619447718.938432
# Episode 172 completed, timesteps played: 3767, return: 11, speed: 17176.970961, epsilon: 0.962330
# Mean return of last 100 games: 21.200000
# Start episode 173
# float32
# frame_idx = 3805.000000, ts = 1619447718.938697, tsframe = 3767.000000, time = 1619447718.939634
# Episode 173 completed, timesteps played: 3805, return: 38, speed: 39539.457207, epsilon: 0.961950
# Mean return of last 100 games: 21.330000
# Start episode 174
# float32
# frame_idx = 3815.000000, ts = 1619447718.939752, tsframe = 3805.000000, time = 1619447718.939917
# Episode 174 completed, timesteps played: 3815, return: 10, speed: 55406.922061, epsilon: 0.961850
# Mean return of last 100 games: 21.310000
# Start episode 175
# float32
# frame_idx = 3824.000000, ts = 1619447718.940018, tsframe = 3815.000000, time = 1619447718.940167
# Episode 175 completed, timesteps played: 3824, return: 9, speed: 54708.313043, epsilon: 0.961760
# Mean return of last 100 games: 21.120000
# Start episode 176
# float32
# frame_idx = 3836.000000, ts = 1619447718.940267, tsframe = 3824.000000, time = 1619447718.941508
# Episode 176 completed, timesteps played: 3836, return: 12, speed: 9480.438501, epsilon: 0.961640
# Mean return of last 100 games: 21.000000
# Start episode 177
# float32
# frame_idx = 3885.000000, ts = 1619447718.941808, tsframe = 3836.000000, time = 1619447718.943223
# Episode 177 completed, timesteps played: 3885, return: 49, speed: 34066.119012, epsilon: 0.961150
# Mean return of last 100 games: 21.350000
# Start episode 178
# float32
# frame_idx = 3901.000000, ts = 1619447718.943340, tsframe = 3885.000000, time = 1619447718.944044
# Episode 178 completed, timesteps played: 3901, return: 16, speed: 21988.487549, epsilon: 0.960990
# Mean return of last 100 games: 21.280000
# Start episode 179
# float32
# frame_idx = 3917.000000, ts = 1619447718.944160, tsframe = 3901.000000, time = 1619447718.944414
# Episode 179 completed, timesteps played: 3917, return: 16, speed: 59178.892416, epsilon: 0.960830
# Mean return of last 100 games: 21.260000
# Start episode 180
# float32
# frame_idx = 3943.000000, ts = 1619447718.944888, tsframe = 3917.000000, time = 1619447718.945548
# Episode 180 completed, timesteps played: 3943, return: 26, speed: 38076.782123, epsilon: 0.960570
# Mean return of last 100 games: 21.390000
# Start episode 181
# float32
# frame_idx = 3966.000000, ts = 1619447718.945662, tsframe = 3943.000000, time = 1619447718.946016
# Episode 181 completed, timesteps played: 3966, return: 23, speed: 37890.413197, epsilon: 0.960340
# Mean return of last 100 games: 21.500000
# Start episode 182
# float32
# frame_idx = 3985.000000, ts = 1619447718.946364, tsframe = 3966.000000, time = 1619447718.946663
# Episode 182 completed, timesteps played: 3985, return: 19, speed: 55806.565826, epsilon: 0.960150
# Mean return of last 100 games: 21.270000
# Start episode 183
# float32
# frame_idx = 3998.000000, ts = 1619447718.946789, tsframe = 3985.000000, time = 1619447718.947603
# Episode 183 completed, timesteps played: 3998, return: 13, speed: 15499.133599, epsilon: 0.960020
# Mean return of last 100 games: 21.290000
# Start episode 184
# float32
# frame_idx = 4014.000000, ts = 1619447718.947720, tsframe = 3998.000000, time = 1619447718.947973
# ...
# Episode 939 completed, timesteps played: 20041, return: 11, speed: 517.710721, epsilon: 0.799590
# Mean return of last 100 games: 20.460000
# Start episode 940
# float32
# frame_idx = 20059.000000, ts = 1619447738.674168, tsframe = 20041.000000, time = 1619447738.708238
# Episode 940 completed, timesteps played: 20059, return: 18, speed: 527.939582, epsilon: 0.799410
# Mean return of last 100 games: 20.510000
# Start episode 941
# float32
# frame_idx = 20079.000000, ts = 1619447738.708341, tsframe = 20059.000000, time = 1619447738.745199
# Episode 941 completed, timesteps played: 20079, return: 20, speed: 542.239517, epsilon: 0.799210
# Mean return of last 100 games: 20.510000
# Start episode 942
# float32
# frame_idx = 20102.000000, ts = 1619447738.745633, tsframe = 20079.000000, time = 1619447738.788397
# Episode 942 completed, timesteps played: 20102, return: 23, speed: 537.527537, epsilon: 0.798980
# Mean return of last 100 games: 20.590000
# Start episode 943
# float32
# frame_idx = 20114.000000, ts = 1619447738.788501, tsframe = 20102.000000, time = 1619447738.810521
# Episode 943 completed, timesteps played: 20114, return: 12, speed: 544.337775, epsilon: 0.798860
# Mean return of last 100 games: 20.520000
# Start episode 944
# float32
# frame_idx = 20151.000000, ts = 1619447738.810927, tsframe = 20114.000000, time = 1619447738.883684
# Episode 944 completed, timesteps played: 20151, return: 37, speed: 508.315557, epsilon: 0.798490
# Mean return of last 100 games: 20.720000
# Start episode 945
# float32
# frame_idx = 20165.000000, ts = 1619447738.884195, tsframe = 20151.000000, time = 1619447738.910071
# Episode 945 completed, timesteps played: 20165, return: 14, speed: 540.493143, epsilon: 0.798350
# Mean return of last 100 games: 20.660000
# Start episode 946
# float32
# frame_idx = 20174.000000, ts = 1619447738.910404, tsframe = 20165.000000, time = 1619447738.928071
# Episode 946 completed, timesteps played: 20174, return: 9, speed: 508.688228, epsilon: 0.798260
# Mean return of last 100 games: 20.600000
# Start episode 947
# float32
# frame_idx = 20211.000000, ts = 1619447738.928176, tsframe = 20174.000000, time = 1619447738.997188
# Episode 947 completed, timesteps played: 20211, return: 37, speed: 535.928142, epsilon: 0.797890
# Mean return of last 100 games: 20.860000
# Start episode 948
# float32
# frame_idx = 20225.000000, ts = 1619447738.997294, tsframe = 20211.000000, time = 1619447739.023920
# Episode 948 completed, timesteps played: 20225, return: 14, speed: 525.268188, epsilon: 0.797750
# Mean return of last 100 games: 20.870000
# Start episode 949
# float32
# frame_idx = 20254.000000, ts = 1619447739.024415, tsframe = 20225.000000, time = 1619447739.077227
# Episode 949 completed, timesteps played: 20254, return: 29, speed: 548.846516, epsilon: 0.797460
# Mean return of last 100 games: 20.930000
# Start episode 950
# float32
# frame_idx = 20285.000000, ts = 1619447739.077335, tsframe = 20254.000000, time = 1619447739.136374
# Episode 950 completed, timesteps played: 20285, return: 31, speed: 524.804340, epsilon: 0.797150
# Mean return of last 100 games: 21.040000
# Start episode 951
# float32
# frame_idx = 20329.000000, ts = 1619447739.136745, tsframe = 20285.000000, time = 1619447739.218254
# Episode 951 completed, timesteps played: 20329, return: 44, speed: 539.649617, epsilon: 0.796710
# Mean return of last 100 games: 21.270000
# Start episode 952
# float32
# frame_idx = 20351.000000, ts = 1619447739.218660, tsframe = 20329.000000, time = 1619447739.275371
# Episode 952 completed, timesteps played: 20351, return: 22, speed: 387.721806, epsilon: 0.796490
# Mean return of last 100 games: 21.360000
# Start episode 953
# float32
# frame_idx = 20369.000000, ts = 1619447739.275482, tsframe = 20351.000000, time = 1619447739.328303
# Episode 953 completed, timesteps played: 20369, return: 18, speed: 340.608026, epsilon: 0.796310
# Mean return of last 100 games: 21.240000
# Start episode 954
# float32
# frame_idx = 20393.000000, ts = 1619447739.328812, tsframe = 20369.000000, time = 1619447739.395196
# Episode 954 completed, timesteps played: 20393, return: 24, speed: 361.279460, epsilon: 0.796070
# Mean return of last 100 games: 21.250000
# Start episode 955
# float32
# frame_idx = 20405.000000, ts = 1619447739.395677, tsframe = 20393.000000, time = 1619447739.427355
# Episode 955 completed, timesteps played: 20405, return: 12, speed: 378.498898, epsilon: 0.795950
# Mean return of last 100 games: 21.220000
# Start episode 956
# float32
# frame_idx = 20424.000000, ts = 1619447739.427622, tsframe = 20405.000000, time = 1619447739.470008
# Episode 956 completed, timesteps played: 20424, return: 19, speed: 447.985969, epsilon: 0.795760
# Mean return of last 100 games: 21.190000
# Start episode 957
# float32
# frame_idx = 20437.000000, ts = 1619447739.470113, tsframe = 20424.000000, time = 1619447739.495528
# Episode 957 completed, timesteps played: 20437, return: 13, speed: 511.001949, epsilon: 0.795630
# Mean return of last 100 games: 20.860000
# Start episode 958
# float32
# frame_idx = 20457.000000, ts = 1619447739.495801, tsframe = 20437.000000, time = 1619447739.547034
# Episode 958 completed, timesteps played: 20457, return: 20, speed: 390.175073, epsilon: 0.795430
# Mean return of last 100 games: 20.700000
# Start episode 959
# float32
# frame_idx = 20467.000000, ts = 1619447739.547141, tsframe = 20457.000000, time = 1619447739.573671
# Episode 959 completed, timesteps played: 20467, return: 10, speed: 376.555761, epsilon: 0.795330
# Mean return of last 100 games: 20.350000
# Start episode 960
# float32
# frame_idx = 20484.000000, ts = 1619447739.573777, tsframe = 20467.000000, time = 1619447739.615045
# Episode 960 completed, timesteps played: 20484, return: 17, speed: 411.631199, epsilon: 0.795160
# Mean return of last 100 games: 20.400000
# Start episode 961
# float32
# frame_idx = 20497.000000, ts = 1619447739.615160, tsframe = 20484.000000, time = 1619447739.646468
# Episode 961 completed, timesteps played: 20497, return: 13, speed: 414.873178, epsilon: 0.795030
# Mean return of last 100 games: 20.320000
# Start episode 962
# float32
# frame_idx = 20514.000000, ts = 1619447739.646805, tsframe = 20497.000000, time = 1619447739.690826
# Episode 962 completed, timesteps played: 20514, return: 17, speed: 385.962878, epsilon: 0.794860
# Mean return of last 100 games: 20.160000
# Start episode 963
# float32
# frame_idx = 20534.000000, ts = 1619447739.690930, tsframe = 20514.000000, time = 1619447739.742068
# Episode 963 completed, timesteps played: 20534, return: 20, speed: 390.893239, epsilon: 0.794660
# Mean return of last 100 games: 20.250000
# Start episode 964
# float32
# frame_idx = 20583.000000, ts = 1619447739.742177, tsframe = 20534.000000, time = 1619447739.843484
# Episode 964 completed, timesteps played: 20583, return: 49, speed: 483.523969, epsilon: 0.794170
# Mean return of last 100 games: 20.030000
# Start episode 965
# float32
# frame_idx = 20599.000000, ts = 1619447739.844011, tsframe = 20583.000000, time = 1619447739.874726
# Episode 965 completed, timesteps played: 20599, return: 16, speed: 520.494086, epsilon: 0.794010
# Mean return of last 100 games: 19.970000
# Start episode 966
# float32
# frame_idx = 20610.000000, ts = 1619447739.874831, tsframe = 20599.000000, time = 1619447739.895108
# Episode 966 completed, timesteps played: 20610, return: 11, speed: 541.810649, epsilon: 0.793900
# Mean return of last 100 games: 19.840000
# Start episode 967
# float32
# frame_idx = 20641.000000, ts = 1619447739.895215, tsframe = 20610.000000, time = 1619447739.952986
# Episode 967 completed, timesteps played: 20641, return: 31, speed: 536.351585, epsilon: 0.793590
# Mean return of last 100 games: 19.930000
# Start episode 968
# float32
# frame_idx = 20653.000000, ts = 1619447739.953471, tsframe = 20641.000000, time = 1619447739.976429
# Episode 968 completed, timesteps played: 20653, return: 12, speed: 522.139613, epsilon: 0.793470
# Mean return of last 100 games: 19.890000
# Start episode 969
# float32
# frame_idx = 20673.000000, ts = 1619447739.976824, tsframe = 20653.000000, time = 1619447740.013966
# Episode 969 completed, timesteps played: 20673, return: 20, speed: 538.103815, epsilon: 0.793270
# Mean return of last 100 games: 19.860000
# Start episode 970
# float32
# frame_idx = 20696.000000, ts = 1619447740.014073, tsframe = 20673.000000, time = 1619447740.057375
# Episode 970 completed, timesteps played: 20696, return: 23, speed: 530.778498, epsilon: 0.793040
# Mean return of last 100 games: 19.940000
# Start episode 971
# float32
# frame_idx = 20709.000000, ts = 1619447740.057487, tsframe = 20696.000000, time = 1619447740.083436
# Episode 971 completed, timesteps played: 20709, return: 13, speed: 500.463071, epsilon: 0.792910
# Mean return of last 100 games: 19.740000
# Start episode 972
# float32
# frame_idx = 20724.000000, ts = 1619447740.083543, tsframe = 20709.000000, time = 1619447740.121523
# Episode 972 completed, timesteps played: 20724, return: 15, speed: 394.658972, epsilon: 0.792760
# Mean return of last 100 games: 19.630000
# Start episode 973
# float32
# frame_idx = 20735.000000, ts = 1619447740.121848, tsframe = 20724.000000, time = 1619447740.149405
# Episode 973 completed, timesteps played: 20735, return: 11, speed: 398.804934, epsilon: 0.792650
# Mean return of last 100 games: 19.450000
# Start episode 974
# float32
# frame_idx = 20754.000000, ts = 1619447740.149510, tsframe = 20735.000000, time = 1619447740.198924
# Episode 974 completed, timesteps played: 20754, return: 19, speed: 384.310489, epsilon: 0.792460
# Mean return of last 100 games: 19.520000
# Start episode 975
# float32
# frame_idx = 20767.000000, ts = 1619447740.199036, tsframe = 20754.000000, time = 1619447740.232818
# Episode 975 completed, timesteps played: 20767, return: 13, speed: 384.521742, epsilon: 0.792330
# Mean return of last 100 games: 19.520000
# Start episode 976
# float32
# frame_idx = 20793.000000, ts = 1619447740.232926, tsframe = 20767.000000, time = 1619447740.299016
# Episode 976 completed, timesteps played: 20793, return: 26, speed: 393.216473, epsilon: 0.792070
# Mean return of last 100 games: 19.560000
# Start episode 977
# float32
# frame_idx = 20813.000000, ts = 1619447740.299129, tsframe = 20793.000000, time = 1619447740.348570
# Episode 977 completed, timesteps played: 20813, return: 20, speed: 404.317029, epsilon: 0.791870
# Mean return of last 100 games: 19.610000
# Start episode 978
# float32
# frame_idx = 20826.000000, ts = 1619447740.348678, tsframe = 20813.000000, time = 1619447740.373217
# Episode 978 completed, timesteps played: 20826, return: 13, speed: 529.177806, epsilon: 0.791740
# Mean return of last 100 games: 19.610000
# Start episode 979
# float32
# frame_idx = 20838.000000, ts = 1619447740.373718, tsframe = 20826.000000, time = 1619447740.396403
# Episode 979 completed, timesteps played: 20838, return: 12, speed: 528.394062, epsilon: 0.791620
# Mean return of last 100 games: 19.610000
# Start episode 980
# float32
# frame_idx = 20877.000000, ts = 1619447740.396509, tsframe = 20838.000000, time = 1619447740.469565
# Episode 980 completed, timesteps played: 20877, return: 39, speed: 533.635167, epsilon: 0.791230
# Mean return of last 100 games: 19.920000
# Start episode 981
# float32
# frame_idx = 20900.000000, ts = 1619447740.469672, tsframe = 20877.000000, time = 1619447740.512429
# Episode 981 completed, timesteps played: 20900, return: 23, speed: 537.536522, epsilon: 0.791000
# Mean return of last 100 games: 19.920000
# Start episode 982
# float32
# frame_idx = 20924.000000, ts = 1619447740.512549, tsframe = 20900.000000, time = 1619447740.558117
# Episode 982 completed, timesteps played: 20924, return: 24, speed: 526.371554, epsilon: 0.790760
# Mean return of last 100 games: 19.950000
# Start episode 983
# float32
# frame_idx = 20935.000000, ts = 1619447740.558493, tsframe = 20924.000000, time = 1619447740.579813
# Episode 983 completed, timesteps played: 20935, return: 11, speed: 515.316803, epsilon: 0.790650
# Mean return of last 100 games: 19.750000
# Start episode 984
# float32
# frame_idx = 20948.000000, ts = 1619447740.579920, tsframe = 20935.000000, time = 1619447740.604448
# Episode 984 completed, timesteps played: 20948, return: 13, speed: 529.450139, epsilon: 0.790520
# Mean return of last 100 games: 19.640000
# Start episode 985
# float32
# frame_idx = 20959.000000, ts = 1619447740.604863, tsframe = 20948.000000, time = 1619447740.625608
# Episode 985 completed, timesteps played: 20959, return: 11, speed: 529.614234, epsilon: 0.790410
# Mean return of last 100 games: 19.530000
# Start episode 986
# float32
# frame_idx = 20968.000000, ts = 1619447740.625711, tsframe = 20959.000000, time = 1619447740.642754
# Episode 986 completed, timesteps played: 20968, return: 9, speed: 527.290627, epsilon: 0.790320
# Mean return of last 100 games: 19.520000
# Start episode 987
# float32
# frame_idx = 20982.000000, ts = 1619447740.642985, tsframe = 20968.000000, time = 1619447740.668945
# Episode 987 completed, timesteps played: 20982, return: 14, speed: 538.747601, epsilon: 0.790180
# Mean return of last 100 games: 19.540000
# Start episode 988
# float32
# frame_idx = 20997.000000, ts = 1619447740.669051, tsframe = 20982.000000, time = 1619447740.696933
# Episode 988 completed, timesteps played: 20997, return: 15, speed: 537.487805, epsilon: 0.790030
# Mean return of last 100 games: 19.570000
# Start episode 989
# float32
# frame_idx = 21007.000000, ts = 1619447740.697038, tsframe = 20997.000000, time = 1619447740.716552
# Episode 989 completed, timesteps played: 21007, return: 10, speed: 511.637756, epsilon: 0.789930
# Mean return of last 100 games: 19.540000
# Start episode 990
# float32
# frame_idx = 21017.000000, ts = 1619447740.716672, tsframe = 21007.000000, time = 1619447740.735900
# Episode 990 completed, timesteps played: 21017, return: 10, speed: 519.386292, epsilon: 0.789830
# Mean return of last 100 games: 19.140000
# Start episode 991
# float32
# frame_idx = 21033.000000, ts = 1619447740.736360, tsframe = 21017.000000, time = 1619447740.767389
# Episode 991 completed, timesteps played: 21033, return: 16, speed: 515.227246, epsilon: 0.789670
# Mean return of last 100 games: 19.210000
# Start episode 992
# float32
# frame_idx = 21061.000000, ts = 1619447740.767491, tsframe = 21033.000000, time = 1619447740.819985
# Episode 992 completed, timesteps played: 21061, return: 28, speed: 533.134704, epsilon: 0.789390
# Mean return of last 100 games: 19.230000
# Start episode 993
# float32
# frame_idx = 21084.000000, ts = 1619447740.820420, tsframe = 21061.000000, time = 1619447740.863469
# Episode 993 completed, timesteps played: 21084, return: 23, speed: 533.957270, epsilon: 0.789160
# Mean return of last 100 games: 19.360000
# Start episode 994
# float32
# frame_idx = 21095.000000, ts = 1619447740.863859, tsframe = 21084.000000, time = 1619447740.883956
# Episode 994 completed, timesteps played: 21095, return: 11, speed: 546.683382, epsilon: 0.789050
# Mean return of last 100 games: 19.230000
# Start episode 995
# float32
# frame_idx = 21110.000000, ts = 1619447740.884436, tsframe = 21095.000000, time = 1619447740.911961
# Episode 995 completed, timesteps played: 21110, return: 15, speed: 544.441406, epsilon: 0.788900
# Mean return of last 100 games: 19.260000
# Start episode 996
# float32
# frame_idx = 21122.000000, ts = 1619447740.912068, tsframe = 21110.000000, time = 1619447740.935767
# Episode 996 completed, timesteps played: 21122, return: 12, speed: 505.683077, epsilon: 0.788780
# Mean return of last 100 games: 19.070000
# Start episode 997
# float32
# frame_idx = 21147.000000, ts = 1619447740.936227, tsframe = 21122.000000, time = 1619447740.982929
# Episode 997 completed, timesteps played: 21147, return: 25, speed: 535.004133, epsilon: 0.788530
# Mean return of last 100 games: 19.200000
# Start episode 998
# float32
# frame_idx = 21172.000000, ts = 1619447740.983038, tsframe = 21147.000000, time = 1619447741.030112
# Episode 998 completed, timesteps played: 21172, return: 25, speed: 530.787493, epsilon: 0.788280
# Mean return of last 100 games: 18.930000
# Start episode 999
# float32
# frame_idx = 21185.000000, ts = 1619447741.030522, tsframe = 21172.000000, time = 1619447741.055640
# Episode 999 completed, timesteps played: 21185, return: 13, speed: 517.024796, epsilon: 0.788150
# Mean return of last 100 games: 18.940000

# %%
batch = replay_memory.sample(32)
states, actions, rewards, dones, next_states = batch

# %%
states
# Out:
# array([[-0.23509048, -0.99674344,  0.14202823,  1.205893  ],
#        [-0.01221185,  0.2033036 , -0.01137768, -0.39452153],
#        [ 0.01403981,  0.38471097, -0.06356827, -0.6559813 ],
#        [ 0.02471143,  0.00704753, -0.02086607,  0.0056784 ],
#        [ 0.04553305, -0.03973223, -0.03497742,  0.04182764],
#        [ 0.07546449,  0.22233449, -0.07402361, -0.33955365],
#        [-0.02647018,  0.23083852, -0.04325013, -0.6108779 ],
#        [ 0.01288328,  0.04091272,  0.06666889,  0.16054414],
#        [-0.03464189,  0.19988637, -0.01580142, -0.389599  ],
#        [-0.13472049, -0.57529694, -0.0236813 ,  0.26569486],
#        [ 0.00225858, -0.4042985 , -0.0386311 ,  0.5520086 ],
#        [-0.04573006,  0.195285  ,  0.0571992 , -0.18666917],
#        [ 0.0150539 , -0.22190392,  0.03292352,  0.34754074],
#        [ 0.13244607,  1.1784552 , -0.17124087, -1.856896  ],
#        [ 0.02920668,  0.62964714,  0.01218806, -0.7824796 ],
#        [-0.0029187 ,  0.21680176,  0.06969614,  0.00571806],
#        [ 0.02098421,  0.3697107 , -0.03042569, -0.5475714 ],
#        [-0.022212  ,  0.34878048,  0.03855944, -0.59628475],
#        [-0.08152738, -0.35320824,  0.10082749,  0.80493927],
#        [-0.00758264, -0.20468713,  0.0140002 ,  0.31637052],
#        [-0.01159954,  0.15446207, -0.0647224 , -0.33783177],
#        [-0.00847186, -0.20567432,  0.03070044,  0.28570393],
#        [ 0.04828475, -0.54507977, -0.09938787,  0.5284402 ],
#        [ 0.01953655, -0.04711934, -0.01350247, -0.01046735],
#        [ 0.09779641,  0.5656992 , -0.09076363, -0.9376768 ],
#        [ 0.03250981,  0.0138669 , -0.0091104 , -0.00898942],
#        [-0.00899292,  0.18774535, -0.03108084, -0.36495802],
#        [-0.0025145 , -0.02053595, -0.01165705,  0.08512368],
#        [ 0.04731261, -0.60800356, -0.01524047,  0.8959149 ],
#        [ 0.00634827,  0.4353857 ,  0.02731203, -0.5691087 ],
#        [ 0.088243  ,  0.76739407, -0.10726819, -1.2200834 ],
#        [-0.08887658, -0.92987067,  0.09143082,  1.4893149 ]],
#       dtype=float32)

# %%
ENV_NAME = "CartPole-v0"
env = gym.make(ENV_NAME)
x=[]
for i in range(32):
    x.append(env.reset())
x
# Out:
# [array([-0.0243938 , -0.02700503, -0.00631201, -0.02593988]),
#  array([ 3.97240209e-03, -2.10942985e-02, -7.00966233e-03, -7.57605349e-05]),
#  array([ 0.02826306, -0.04461565,  0.028929  ,  0.04662189]),
#  array([-0.04987784,  0.00602483,  0.04034786,  0.04221054]),
#  array([-0.04907038,  0.00118571,  0.02718911, -0.01325019]),
#  array([ 0.00278728,  0.02502537, -0.02910984,  0.04138255]),
#  array([ 0.02125563, -0.01070709, -0.01323864, -0.01632808]),
#  array([-0.02007005,  0.04879822,  0.03645241, -0.02047673]),
#  array([-0.0234892 , -0.03666565, -0.04548653, -0.01133783]),
#  array([ 0.0397614 ,  0.0072732 ,  0.02193817, -0.01645931]),
#  array([ 0.01814969, -0.02026478,  0.03972562, -0.04069806]),
#  array([-0.00868179,  0.01349155,  0.01389249, -0.00343418]),
#  array([ 0.03027661,  0.0090223 ,  0.030169  , -0.00435507]),
#  array([-0.02088356,  0.00168808,  0.0410512 , -0.03460227]),
#  array([-0.047762  ,  0.01205452, -0.01435437, -0.04210863]),
#  array([-0.02007547,  0.00981842,  0.01450585, -0.0070389 ]),
#  array([ 0.03867379,  0.00743772, -0.03201912, -0.02259671]),
#  array([-3.84254026e-05,  4.74899786e-03,  2.44183467e-02,  2.68179768e-02]),
#  array([-0.02166709, -0.00773661, -0.02658363, -0.04077449]),
#  array([ 0.01675839, -0.00587907,  0.04577262,  0.03533426]),
#  array([ 0.02513004,  0.02242314, -0.02998863,  0.01859257]),
#  array([-0.00688793, -0.01495193,  0.04525325,  0.03171718]),
#  array([ 0.02806493,  0.03527459, -0.01654146,  0.03254217]),
#  array([ 0.04497547,  0.03849569, -0.00930282, -0.0324151 ]),
#  array([-0.02839403,  0.00352618,  0.00255602, -0.02060245]),
#  array([ 0.00946837,  0.04514514,  0.04569202, -0.01356743]),
#  array([-0.03546607,  0.02143723,  0.01625849,  0.04253361]),
#  array([0.00357867, 0.03882192, 0.03636311, 0.03983889]),
#  array([ 0.04832085,  0.02968877, -0.03925902, -0.01913558]),
#  array([ 0.00128748, -0.04623317, -0.0042665 , -0.00733046]),
#  array([ 0.03372738,  0.01274919, -0.04480918, -0.04839279]),
#  array([-0.01621644, -0.00598874,  0.00957367, -0.02038087])]
